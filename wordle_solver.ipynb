# %%
from wordle_solver import wordle_solver
ws = wordle_solver()

ws.update_information(word='raise', result='bbgbb')
ws.update_information(word='icily', result='bbgbb')
#ws.update_information(word='crony', result='bggbg')

ws.get_compatible_word_scores()
# Out:
#        SumScore  AvgScore
# Word
# owing        17  1.307692
# doing        19  1.461538
# going        19  1.461538
# joint        19  1.461538
# point        19  1.461538
# thing        23  1.769231
# think        23  1.769231
# thigh        27  2.076923
# onion        33  2.538462
# opium        41  3.153846
# twixt        41  3.153846
# union        41  3.153846
# whiff        63  4.846154
